# %%
import os

# %%
modubft = "../../aws/benchmark/out/modubft/20251025-215157-large/"

# %%
modubft_n_21 = os.path.join(modubft,"20251025222547-cb1-v512")
modubft_n_3 = os.path.join(modubft,"20251025215534-cb1-v512")
"../../aws/benchmark/out/modubft/20251025-215157-large/20251025215534-cb1-v512"

# %%
# %%bash
# echo "ModuBFT n=21"
# go tool pprof -lines -tree  -cum -noinlines  "../../aws/benchmark/out/modubft/20251025-215157-large/20251025222547-cb1-v512/cli" "../../aws/benchmark/out/modubft/20251025-215157-large/20251025222547-cb1-v512/cpu.prof"
# Out:
# ModuBFT n=21
# File: cli
# Build ID: 9f11368d7e382048155d769d498b8d573b3ab670
# Type: cpu
# Time: 2025-10-25 22:26:10 CEST
# Duration: 23.52s, Total samples = 20.29s (86.25%)
# Showing nodes accounting for 3.41s, 16.81% of 20.29s total
# Dropped 847 nodes (cum <= 0.10s)
# Showing top 80 nodes out of 193
# ----------------------------------------------------------+-------------
#       flat  flat%   sum%        cum   cum%   calls calls% + context
# ----------------------------------------------------------+-------------
#                                              2.36s 61.46% |   runtime.gcBgMarkWorker /usr/local/go/src/runtime/mgc.go:1523
#                                              0.65s 16.93% |   runtime.gcAssistAlloc /usr/local/go/src/runtime/mgcmark.go:580
#                                              0.17s  4.43% |   runtime.chansend1 /usr/local/go/src/runtime/chan.go:161
# ...

# %%
# %%bash
# echo "ModuBFT n=3"
# go tool pprof -lines -tree  -nodecount=50 -cum -noinlines  "../../aws/benchmark/out/modubft/20251025-215157-large/20251025215534-cb1-v512/cli" "../../aws/benchmark/out/modubft/20251025-215157-large/20251025215534-cb1-v512/cpu.prof"
# Out:
# ModuBFT n=3
# File: cli
# Build ID: 9f11368d7e382048155d769d498b8d573b3ab670
# Type: cpu
# Time: 2025-10-25 21:55:41 CEST
# Duration: 23.43s, Total samples = 28.05s (119.72%)
# Showing nodes accounting for 2.74s, 9.77% of 28.05s total
# Dropped 1201 nodes (cum <= 0.14s)
# Showing top 50 nodes out of 209
# ----------------------------------------------------------+-------------
#       flat  flat%   sum%        cum   cum%   calls calls% + context
# ----------------------------------------------------------+-------------
#          0     0%     0%      7.27s 25.92%                | modubft/node.(*Node).verifyMessageSignature /mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/modubft/node/communication.go:439
#                                              5.56s 76.48% |   modubft/node.(*Node).VerifySig /mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/modubft/node/keys.go:90
# ...

# %%
alternatingnonoptimistic = "../../aws/benchmark/out/geobft/final-geobft-alternating-non-optimistic/"
notalternatingnonoptimistic="../../aws/benchmark/out/geobft/final-geobft-not-alternating-non-optimistic/"

alternatingnonoptimisticK6n3bc64 = os.path.join(alternatingnonoptimistic,"20251028160252-cb128-v512")
notalternatingnonoptimisticK6n3bc64= os.path.join(notalternatingnonoptimistic,"20251030140148-cb128-v512")

# %%
# echo "Alternating Non-Optimistic Profile nc=3 cb=128 k=6 v=512"
# go tool pprof -tree -nodecount=50 -cum -noinlines  "{alternatingnonoptimisticK6n3bc64}/cli" "{alternatingnonoptimisticK6n3bc64}/cpu.prof"

# echo "Not Alternating Non-Optimistic Profile nc=3 cb=128 k=6 v=512"
# go tool pprof -tree -nodecount=50 -cum -noinlines  "{notalternatingnonoptimisticK6n3bc64}/cli" "{notalternatingnonoptimisticK6n3bc64}/cpu.prof"

# %%
# %%bash
# echo "profile of a multi leader bucket leader for nc=3 and k=6 and bc=128 and v=512"
# go tool pprof -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103407-cb128-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103407-cb128-v512/cpu_0.prof"
# echo "profile of a multi leader bucket leader for nc=3 and k=6 and bc=1  and v=512"
# go tool pprof -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106102640-cb1-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106102640-cb1-v512/cpu_0.prof"
#
#
# echo "profile of a multi leader bucket leader for nc=3 and k=6 and bc=128 and v=4096"
# go tool pprof -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103522-cb128-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103522-cb128-v4096/cpu_0.prof"
# echo "profile of a multi leader bucket leader for nc=3 and k=6 and bc=1  and v=4096"
# go tool pprof -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106102757-cb1-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106102757-cb1-v4096/cpu_0.prof"
# Out:
# profile of a bucket leader for nc=3 and k=6 and bc=128 and v=512
# File: cli
# Build ID: 4d0b427a73df88ad2d07f06bdaa597ab5cf7ad0e
# Type: cpu
# Time: 2025-11-06 10:34:38 CET
# Duration: 18.56s, Total samples = 22.15s (119.35%)
# Showing nodes accounting for 8.42s, 38.01% of 22.15s total
# Dropped 256 nodes (cum <= 0.11s)
# Showing top 50 nodes out of 187
# ----------------------------------------------------------+-------------
#       flat  flat%   sum%        cum   cum%   calls calls% + context
# ----------------------------------------------------------+-------------
#                                              2.62s 56.96% |   runtime.gcBgMarkWorker
#                                              0.93s 20.22% |   runtime.mallocgc
#                                              0.27s  5.87% |   runtime.chansend1
#                                              0.11s  2.39% |   modubft/node.(*Node).VerifySig
# ...

# %%
# %%bash
# # echo "profile of a multi leader 4 bucket leader for nc=6 and k=6 and bc=120 and v=512"
# # go tool pprof  -tree -nodecount=50 -cum   "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-4-buckets/20251106151152-cb120-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-4-buckets/20251106151152-cb120-v512/cpu_0.prof"
#
#
# echo "profile of a multi leader 4 bucket leader for nc=6 and k=6 and bc=120 and v=4096"
# go tool pprof  -tree  -cum   "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-4-buckets/20251106151416-cb120-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-4-buckets/20251106151416-cb120-v4096/cpu_0.prof"
#
#
# # echo "profile of a multi leader bucket leader for nc=6 and k=6 and bc=120 and v=512"
# # go tool pprof  -tree -nodecount=50 -cum   "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103407-cb128-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103407-cb128-v512/cpu_0.prof"
#
#
# # echo "profile of a multi leader bucket leader for nc=6 and k=6 and bc=120 and v=4096"
# # go tool pprof  -tree -nodecount=50 -cum   "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103522-cb128-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-2-buckets/20251106103522-cb128-v4096/cpu_0.prof"
# Out:
# profile of a multi leader 4 bucket leader for nc=6 and k=6 and bc=120 and v=4096
# File: cli
# Build ID: 4d0b427a73df88ad2d07f06bdaa597ab5cf7ad0e
# Type: cpu
# Time: 2025-11-06 15:15:17 CET
# Duration: 19.18s, Total samples = 19.99s (104.23%)
# Showing nodes accounting for 11.88s, 59.43% of 19.99s total
# Dropped 375 nodes (cum <= 0.10s)
# Showing top 80 nodes out of 197
# ----------------------------------------------------------+-------------
#       flat  flat%   sum%        cum   cum%   calls calls% + context
# ----------------------------------------------------------+-------------
#      0.09s  0.45%  0.45%      4.46s 22.31%                | modubft/node.(*Node).sendMessageToPeer
#                                              1.67s 37.44% |   net.(*conn).Write
#                                              1.60s 35.87% |   github.com/golang/protobuf/proto.Marshal (inline)
#                                              0.52s 11.66% |   runtime.growslice
# ...

# %%
# %%bash
# echo "profile of a multi leader 4 bucket leader for nc=6 and k=6 and bc=120 and v=512"
# go tool pprof -lines -top  -flat -noinlines "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-4-buckets/20251106155543-cb120-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/final-multileader-geobft-with-non-optimistic-global-sharing-4-buckets/20251106155543-cb120-v4096/cpu_11.prof"
# Out:
# profile of a multi leader 4 bucket leader for nc=6 and k=6 and bc=120 and v=512
# File: cli
# Build ID: 4d0b427a73df88ad2d07f06bdaa597ab5cf7ad0e
# Type: cpu
# Time: 2025-11-06 15:56:07 CET
# Duration: 18.44s, Total samples = 21.41s (116.08%)
# Showing nodes accounting for 6.44s, 30.08% of 21.41s total
# Dropped 1062 nodes (cum <= 0.11s)
#       flat  flat%   sum%        cum   cum%
#      2.61s 12.19% 12.19%      2.61s 12.19%  internal/runtime/syscall.Syscall6 /usr/local/go/src/internal/runtime/syscall/asm_linux_amd64.s:36
#      0.30s  1.40% 13.59%      0.30s  1.40%  runtime.scanobject /usr/local/go/src/runtime/mgcmark.go:1507
#      0.29s  1.35% 14.95%      0.29s  1.35%  runtime.futex /usr/local/go/src/runtime/sys_linux_amd64.s:558
#      0.29s  1.35% 16.30%      0.29s  1.35%  runtime.mallocgcSmallScanNoHeader /usr/local/go/src/runtime/malloc.go:1376
# ...

# %%
# %%bash
#
# # echo "profile nonoptimistic global sharing for nc=6 and k=6 and bc=128 and v=512"
# # go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251106235550-cb128-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251106235550-cb128-v512/cpu_0.prof"
# echo "profile single leader (nonoptimistic global sharing) for nc=6 and k=6 and bc=128 and v=4096"
# go tool pprof -lines -tree -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251106235803-cb128-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251106235803-cb128-v4096/cpu_0.prof"
#
# # echo "profile nonoptimistic global sharing for nc=3 and k=6 and bc=128 and v=512"
# # go tool pprof -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251107000850-cb128-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251107000850-cb128-v512/cpu_0.prof"
# # echo "profile nonoptimistic global sharing for nc=3 and k=6 and bc=128 and v=4096"
# # go tool pprof -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251107000953-cb128-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/non-optimistic-profiling/20251107000953-cb128-v4096/cpu_0.prof"
# Out:
# profile single leader (nonoptimistic global sharing) for nc=6 and k=6 and bc=128 and v=4096
# File: cli
# Build ID: 4d0b427a73df88ad2d07f06bdaa597ab5cf7ad0e
# Type: cpu
# Time: 2025-11-06 23:58:44 CET
# Duration: 18.68s, Total samples = 27.10s (145.05%)
# Showing nodes accounting for 9.23s, 34.06% of 27.10s total
# Dropped 1013 nodes (cum <= 0.14s)
# Showing top 80 nodes out of 177
# ----------------------------------------------------------+-------------
#       flat  flat%   sum%        cum   cum%   calls calls% + context
# ----------------------------------------------------------+-------------
#                                              2.67s 46.68% |   runtime.gcBgMarkWorker /usr/local/go/src/runtime/mgc.go:1523
#                                              1.69s 29.55% |   runtime.gcAssistAlloc /usr/local/go/src/runtime/mgcmark.go:580
#                                              0.24s  4.20% |   runtime.mallocgc /usr/local/go/src/runtime/malloc.go:1059
# ...

# %%
# %%bash
#
# echo "profile alternating nonoptimistic global sharing for nc=6 and k=6 and bc=128 and v=512"
# go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/alternating-non-optimistic-profiling/20251107002852-cb128-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/alternating-non-optimistic-profiling/20251107002852-cb128-v512/cpu_0.prof"
# echo "profile alternating nonoptimistic global sharing for nc=6 and k=6 and bc=128 and v=4096"
# go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/alternating-non-optimistic-profiling/20251107003053-cb128-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/alternating-non-optimistic-profiling/20251107003053-cb128-v4096/cpu_0.prof"
# Out:
# profile alternating nonoptimistic global sharing for nc=6 and k=6 and bc=128 and v=512
# File: cli
# Build ID: 4d0b427a73df88ad2d07f06bdaa597ab5cf7ad0e
# Type: cpu
# Time: 2025-11-07 00:29:36 CET
# Duration: 18.99s, Total samples = 21.47s (113.07%)
# Showing nodes accounting for 1.96s, 9.13% of 21.47s total
# Dropped 1094 nodes (cum <= 0.11s)
# Showing top 50 nodes out of 237
# ----------------------------------------------------------+-------------
#       flat  flat%   sum%        cum   cum%   calls calls% + context
# ----------------------------------------------------------+-------------
#          0     0%     0%      4.14s 19.28%                | modubft/node.(*Node).verifyMessageSignature /mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/modubft/node/communication.go:439
# ...

# %%
# %%bash
#
#
# echo "profile geobft nc=6 and k=6 and bc=128 and v=4096"
# go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107010115-cb128-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107010115-cb128-v4096/cpu_0.prof"
#
# # echo "profile geobft for nc=6 and k=2 and bc=128 and v=512"
# # go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012615-cb128-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012615-cb128-v512/cpu_0.prof"
# # echo "profile geobft nc=6 and k=2 and bc=128 and v=4096"
# # go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012659-cb128-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012659-cb128-v4096/cpu_0.prof"
#
#
# # echo "profile geobft for nc=6 and k=6 and bc=1 and v=512"
# # go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012442-cb1-v512/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012442-cb1-v512/cpu_0.prof"
# # echo "profile geobft nc=6 and k=6 and bc=1 and v=4096"
# # go tool pprof -lines -tree -nodecount=50 -cum -noinlines  "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012531-cb1-v4096/cli" "/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/benchmark/out/geobft/geobft-profiling/20251107012531-cb1-v4096/cpu_0.prof"
# Out:
# profile geobft nc=6 and k=6 and bc=128 and v=4096
# File: cli
# Build ID: 4d0b427a73df88ad2d07f06bdaa597ab5cf7ad0e
# Type: cpu
# Time: 2025-11-07 01:01:58 CET
# Duration: 18.82s, Total samples = 26.76s (142.19%)
# Showing nodes accounting for 3.84s, 14.35% of 26.76s total
# Dropped 1046 nodes (cum <= 0.13s)
# Showing top 50 nodes out of 179
# ----------------------------------------------------------+-------------
#       flat  flat%   sum%        cum   cum%   calls calls% + context
# ----------------------------------------------------------+-------------
#                                              2.99s 49.02% |   runtime.gcBgMarkWorker /usr/local/go/src/runtime/mgc.go:1523
#                                              1.69s 27.70% |   runtime.gcAssistAlloc /usr/local/go/src/runtime/mgcmark.go:580
#                                              0.28s  4.59% |   runtime.mallocgc /usr/local/go/src/runtime/malloc.go:1072
# ...
