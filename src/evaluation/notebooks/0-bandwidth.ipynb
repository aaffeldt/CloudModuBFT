# %% [markdown]
# ```bash
# terraform plan -out "plan" -var=region="eu-central-1" -var=ami="ami-0a116fa7c861dd5f9" -var=instance_type="c5a.xlarge" -var=client_instance_type="c5a.large" -var=number_of_nodes="4" -var=number_of_clients="0" -var=number_of_node_spread_groups="1" -var=list_of_node_azs="eu-central-1a,eu-central-1b,eu-central-1c,eu-central-1a" -var=list_of_client_azs="" -var=list_of_node_spread_group=[0,0,0,0] -var=public_key_path="/mnt/c/Users/Andre/OneDrive/Cloud-Native Byzantine Consensus/code/CloudModuBFT/src/aws/aws_ec2_key.pub" -var=node_az_ids=[0,0,0,1] -var=client_az_ids=[0]
# ```
# ```bash
# terraform apply "plan"
#
# ```

# %% [markdown]
# ```bash
#
#
# wget https://iperf.fr/download/ubuntu/libiperf0_3.1.3-1_amd64.deb
# wget https://iperf.fr/download/ubuntu/iperf3_3.1.3-1_amd64.deb
# dpkg  -x libiperf0_3.1.3-1_amd64.deb libperf3
# dpkg  -x  iperf3_3.1.3-1_amd64.deb iperf3
#
# ssh-keygen -f '/home/andre/.ssh/known_hosts' -R '18.158.217.102'
# scp -i "./aws_ec2_key" -o "StrictHostKeyChecking=no" "./aws_ec2_key" ubuntu@18.158.217.102:"ssh_key"
#
#
#
# scp -r -o StrictHostKeyChecking=no -i "./aws_ec2_key"  ./iperf3/usr/bin/iperf3 ubuntu@18.158.217.102:~/
# scp -r -o StrictHostKeyChecking=no -i "./aws_ec2_key" ./libperf3/usr/lib/x86_64-linux-gnu/ ubuntu@18.158.217.102:~/
#
# ssh -i "./aws_ec2_key" -o "StrictHostKeyChecking=no" ubuntu@18.158.217.102
#
# scp -r -o StrictHostKeyChecking=no -i ~/ssh_key  ~/* ubuntu@12.0.1.143:~/
#
# scp -r -o StrictHostKeyChecking=no -i ~/ssh_key  ~/* ubuntu@12.0.0.143:~/
#
# scp -r -o StrictHostKeyChecking=no -i ~/ssh_key  ~/* ubuntu@12.0.1.15:~/
#
# scp -r -o StrictHostKeyChecking=no -i ~/ssh_key  ~/* ubuntu@12.0.0.144:~/
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.143 "sed -i '1s|^|export LD_LIBRARY_PATH=\$LD_LIBRARY_PATH:~/x86_64-linux-gnu/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.143 "sed -i '1s|^|export PATH=\$PATH:~/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.143 'source ~/.bashrc'
#
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.143 "sed -i '1s|^|export LD_LIBRARY_PATH=\$LD_LIBRARY_PATH:~/x86_64-linux-gnu/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.143 "sed -i '1s|^|export PATH=\$PATH:~/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.143 'source ~/.bashrc'
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.15 "sed -i '1s|^|export LD_LIBRARY_PATH=\$LD_LIBRARY_PATH:~/x86_64-linux-gnu/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.15 "sed -i '1s|^|export PATH=\$PATH:~/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.15 'source ~/.bashrc'
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.144 "sed -i '1s|^|export LD_LIBRARY_PATH=\$LD_LIBRARY_PATH:~/x86_64-linux-gnu/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.144 "sed -i '1s|^|export PATH=\$PATH:~/\\n|' ~/.bashrc"
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.144 'source ~/.bashrc'
#
#
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.143
#
# tmux
# LD_LIBRARY_PATH=$LD_LIBRARY_PATH:~/x86_64-linux-gnu/ ./iperf3 -s
#
# use CTRL + b then d
# exit
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.143
# LD_LIBRARY_PATH=$LD_LIBRARY_PATH:~/x86_64-linux-gnu/ ./iperf3 -c 12.0.0.143 > perf1.txt
#
# ping -c 50   -n -i 0.1 12.0.0.143 > ping1.txt
#
# exit
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.1.15
# LD_LIBRARY_PATH=$LD_LIBRARY_PATH:~/x86_64-linux-gnu/ ./iperf3 -c 12.0.0.143 > perf2.txt
#
# ping -c 50   -n -i 0.1 12.0.0.143 > ping2.txt
#
#
#
# ssh -o StrictHostKeyChecking=no -i ~/ssh_key ubuntu@12.0.0.144
# LD_LIBRARY_PATH=$LD_LIBRARY_PATH:~/x86_64-linux-gnu/ ./iperf3 -c 12.0.0.143 > perf3.txt
# ping -c 50   -n -i 0.1 12.0.0.143 > ping3.txt
#
#
# scp -o StrictHostKeyChecking=no -i ~/ssh_key  ubuntu@12.0.1.143:~/perf1.txt ./perf1.txt
# scp -o StrictHostKeyChecking=no -i ~/ssh_key  ubuntu@12.0.1.15:~/perf2.txt ./perf2.txt
# scp -o StrictHostKeyChecking=no -i ~/ssh_key  ubuntu@12.0.0.144:~/perf3.txt ./perf3.txt
#
# scp -o StrictHostKeyChecking=no -i ~/ssh_key  ubuntu@12.0.1.143:~/ping1.txt ./ping1.txt
# scp -o StrictHostKeyChecking=no -i ~/ssh_key  ubuntu@12.0.1.15:~/ping2.txt ./ping2.txt
# scp -o StrictHostKeyChecking=no -i ~/ssh_key  ubuntu@12.0.0.144:~/ping3.txt ./ping3.txt
#
# scp -o StrictHostKeyChecking=no -i "./aws_ec2_key" ubuntu@18.158.217.102:~/ping*.txt ./
# scp -o StrictHostKeyChecking=no -i "./aws_ec2_key" ubuntu@18.158.217.102:~/perf*.txt ./
#
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## t2.micro
#
#  12.0.0.143: eu-central-1a
#  12.0.1.15: eu-central-1b
# 12.0.1.143: eu-central-1c
#  12.0.0.144 : eu-central-1a
#  12.0.1.143 port 56822 connected to 12.0.0.143: 1.03 Gbits/sec rtt min/avg/max/mdev = 0.889/1.003/1.455/0.085 ms
#  12.0.1.15 port 42700 connected to 12.0.0.143 port 5201 1.03 Gbits/sec rtt min/avg/max/mdev = 0.853/0.961/1.079/0.047 ms
#  12.0.0.144 port 35886 connected to 12.0.0.143 port 5201 1.03 Gbits/sec  rtt min/avg/max/mdev = 0.356/0.544/1.991/0.362 ms
#
#
# ## c5a.xlarge
#
#  12.0.0.143: eu-central-1a
#  12.0.1.15: eu-central-1b
# 12.0.1.143: eu-central-1c
#  12.0.0.144 : eu-central-1a
# 12.0.1.143 port 56822 connected to 12.0.0.143:4.96 Gbits/sec rtt min/avg/max/mdev = 0.642/0.670/0.695/0.011 ms
# 12.0.1.15 port 42700 connected to 12.0.0.143 port 5201 4.96 Gbits/sec rtt min/avg/max/mdev = 0.503/0.530/0.554/0.013 ms
#  12.0.0.144 port 35886 connected to 12.0.0.143 port 5201 4.87 Gbits/sec rtt min/avg/max/mdev = 0.704/0.757/0.980/0.054 ms
#
#  ## c5a.large
#   12.0.0.143: eu-central-1a
#  12.0.1.15: eu-central-1b
# 12.0.1.143: eu-central-1c
#  12.0.0.144 : eu-central-1a
#
#  local 12.0.1.143 port 42984 connected to 12.0.0.143 port 5201  4.96 Gbits/sec   rtt min/avg/max/mdev = 0.728/0.758/0.811/0.014 ms
#
#
#
#  local 12.0.1.15 port 53024 connected to 12.0.0.143 port 5201  4.96 Gbits/sec rtt min/avg/max/mdev = 0.779/0.809/0.838/0.011 ms
#
#
#   12.0.0.144 port 56216 connected to 12.0.0.143 port 5201  4.96 Gbits/sec  rtt min/avg/max/mdev = 0.704/0.757/0.980/0.054 ms
